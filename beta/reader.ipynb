# %%
import csv

# %%
beta_testers_1_csv_file_path = 'beta_testers_1.csv'

# %%
beta_testers_csv_file = open(beta_testers_1_csv_file_path)
reader = csv.DictReader(beta_testers_csv_file)
testers = [row for row in reader]
print(testers)
# Out:
# [{'first_name': 'Jinho', 'last_name': 'Yoon', 'email': 'jinho.yoon@striketutor.com'}, {'first_name': 'Craig', 'last_name': 'Spencer', 'email': 'craig@virtuebowling.com'}, {'first_name': 'Carl', 'last_name': 'Ong', 'email': 'carl@agentongopen.com'}, {'first_name': 'Charles', 'last_name': 'Hutcherson', 'email': 'chutcherson22@gmail.com'}, {'first_name': 'Nick', 'last_name': 'Smith', 'email': 'nick@brunsnick.com'}, {'first_name': 'Katey', 'last_name': 'Furze', 'email': 'bowlingbaddiesclub@gmail.com'}, {'first_name': 'Jasmine', 'last_name': 'Monk', 'email': 'collegebowlingnetwork@gmail.com'}, {'first_name': 'Zack', 'last_name': 'Luetner', 'email': 'zvlbowling@outlook.com'}, {'first_name': 'Bryan', 'last_name': 'Goehring', 'email': 'bryan@midwaylanes.com'}, {'first_name': 'Emily', 'last_name': 'Peterson', 'email': 'lv2bowl05@hotmail.com'}, {'first_name': 'Caity', 'last_name': 'Capozucca', 'email': 'caitycapozucca313@gmail.com'}, {'first_name': 'Kerri', 'last_name': 'Tiezen', 'email': 'ker
# ...
